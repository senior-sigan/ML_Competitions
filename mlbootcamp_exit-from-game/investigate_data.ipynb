# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = (15, 10)

# %%
x = pd.read_csv('data/x_train.csv.gz', delimiter=';')
y = pd.read_csv('data/y_train.csv.gz', names=['target'])

# %%
train = pd.concat([x,y], axis=1)
train.head()
# Out:
#    maxPlayerLevel  numberOfAttemptedLevels  attemptsOnTheHighestLevel  \
# 0              39                       10                          3
# 1              21                       22                         19
# 2               5                        6                          1
# 3              21                        2                          5
# 4               4                        5                          1
#
#    totalNumOfAttempts  averageNumOfTurnsPerCompletedLevel  \
# 0                  17                           24.444444
# 1                  55                           17.045455
# 2                   6                            8.400000
# 3                   6                           19.000000
# 4                   5                            9.600000
#
#    doReturnOnLowerLevels  numberOfBoostersUsed  fractionOfUsefullBoosters  \
# 0                      1                     5                   0.400000
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25289 entries, 0 to 25288
# Data columns (total 13 columns):
# maxPlayerLevel                        25289 non-null int64
# numberOfAttemptedLevels               25289 non-null int64
# attemptsOnTheHighestLevel             25289 non-null int64
# totalNumOfAttempts                    25289 non-null int64
# averageNumOfTurnsPerCompletedLevel    25289 non-null float64
# doReturnOnLowerLevels                 25289 non-null int64
# numberOfBoostersUsed                  25289 non-null int64
# fractionOfUsefullBoosters             25289 non-null float64
# totalScore                            25289 non-null int64
# totalBonusScore                       25289 non-null int64
# totalStarsCount                       25289 non-null int64
# numberOfDaysActuallyPlayed            25289 non-null int64
# target                                25289 non-null int64
# dtypes: float64(2), int64(11)
# memory usage: 2.5 MB

# %%
train.describe()
# Out:
#        maxPlayerLevel  numberOfAttemptedLevels  attemptsOnTheHighestLevel  \
# count    25289.000000             25289.000000               25289.000000
# mean        18.424888                12.415991                   3.507612
# std         20.172964                12.991894                   6.766648
# min          0.000000                 1.000000                   1.000000
# 25%          4.000000                 3.000000                   1.000000
# 50%         11.000000                 8.000000                   1.000000
# 75%         27.000000                16.000000                   3.000000
# max        146.000000               142.000000                 186.000000
#
#        totalNumOfAttempts  averageNumOfTurnsPerCompletedLevel  \
# count        25289.000000                        25289.000000
# mean            26.841393                           13.330451
# std             39.993029                            6.657224
# ...

# %%
train.corr()
# Out:
#                                     maxPlayerLevel  numberOfAttemptedLevels  \
# maxPlayerLevel                            1.000000                 0.616157
# numberOfAttemptedLevels                   0.616157                 1.000000
# attemptsOnTheHighestLevel                 0.472142                 0.300797
# totalNumOfAttempts                        0.757854                 0.836398
# averageNumOfTurnsPerCompletedLevel        0.683706                 0.531197
# doReturnOnLowerLevels                     0.368297                 0.290636
# numberOfBoostersUsed                      0.675955                 0.881915
# fractionOfUsefullBoosters                 0.126235                 0.332887
# totalScore                                0.570234                 0.979954
# totalBonusScore                           0.551366                 0.989014
# totalStarsCount                           0.579593                 0.993779
# ...

# %%
hists = train.hist(figsize=(20,20), bins=100)

# %%
sns.heatmap(train.corr(), square=True)

# %%
sns.heatmap(train.corr().apply(lambda x: x > 0.8), square=True)

# %%
from sklearn.manifold import TSNE
from sklearn.preprocessing import scale
import matplotlib.cm as cm

# %%
data_subset = scale(x)

# %%
tsne = TSNE(n_components=2, random_state=42)
tsne_representation = tsne.fit_transform(data_subset)

# %%
plt.subplots(figsize=(10,10))
colors = cm.rainbow(np.linspace(0, 1, 2))
for y_, c in zip([0,1], colors):
    plt.scatter(tsne_representation[np.ravel(y)==y_, 0], 
                tsne_representation[np.ravel(y)==y_, 1], c=c, alpha=0.5, label=str(y_))
plt.legend()

# %%
sns.pairplot(train, hue='target')
